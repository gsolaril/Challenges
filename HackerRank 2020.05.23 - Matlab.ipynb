# %% [markdown]
# ## MATLAB kernel
#
# {<a href = "https://am111.readthedocs.io/en/latest/jmatlab_install.html">Click this link for installing in Jupyter</a>}

# %%
# %%capture
# !apt install octave

# %% [markdown]
# ## <a href = "https://www.hackerrank.com/challenges/grading/problem">Student grading</a>

# %%
# %%writefile gradingStudents.m
# function y = gradingStudents(grades)
#     for i = 1 : length(grades)
#         cond = (rem(grades(i), 5) > 2) && (grades(i) > 37);
#         y(i) = grades(i) + (5 - rem(grades(i), 5))*cond; end; end
# Out:
# Overwriting gradingStudents.m

# %%
# -W : no window system
# %%writefile gradingStudents_test.m
x = [4, 73, 67, 38, 33];
disp(strcat("Input: ", mat2str(x)));
disp(strcat("Output: ", mat2str(gradingStudents(x))))
# Out:
# Overwriting gradingStudents_test.m

# %%
# !octave -W gradingStudents_test.m
# Out:
# Input:[4 73 67 38 33]
# Output:[4 75 67 40 33]

# %% [markdown]
# ## <a href = "https://www.hackerrank.com/challenges/apple-and-orange/problem">Apple & orange</a>

# %%
# %%writefile countApplesAndOranges.m
# function y = countApplesAndOranges(s, t, a, o, apples, oranges)
#     in_house = @(fruit, tree) s <= tree + fruit <= t;
#     y = [sum(in_house(apples, a)), sum(in_house(oranges, o))]; end
# Out:
# Overwriting countApplesAndOranges.m

# %%
# %%writefile countApplesAndOranges_test.m
# a = 5; s = 7; t = 11; o = 15;
# A = [-2, 2, 1]; O = [5, -6];
# disp(strcat("Input: ", "s =", num2str(s), "; t =", num2str(t)));
# disp(strcat("Input: ", "a =", num2str(a), "; o =", num2str(o)));
# disp(strcat("Input: ", "A =", mat2str(A), "; O =", mat2str(O)));
# disp(strcat("Output: ", mat2str(countApplesAndOranges(s, t, a, o, A, O))))
# Out:
# Overwriting countApplesAndOranges_test.m

# %%
# !octave -W countApplesAndOranges_test.m
# Out:
# Input:s =7; t =11
# Input:a =5; o =15
# Input:A =[-2 2 1]; O =[5 -6]
# Output:[3 2]

# %% [markdown]
# ## <a href = "https://www.hackerrank.com/challenges/minimum-distances/problem">Minimum distances</a>

# %%
# %%writefile minimumDistances.m
# function min_dist = minimumDistances(a)
#     min_dist = inf;
#     for id1 = 1 : numel(a)
#         for id2 = id1 + 1 : numel(a)
#             if (a(id1) == a(id2))
#                 min_dist = min(min_dist, id2 - id1);
#                 break; end; end; end
#     if (min_dist == inf); min_dist = -1; end; end
# Out:
# Overwriting minimumDistances.m

# %%
# %%writefile minimumDistances_test.m
# a = [3, 2, 1, 2, 3];
# disp(strcat("Input: ", mat2str(a)));
# disp(strcat("Output: ", mat2str(minimumDistances(a))))
# Out:
# Overwriting minimumDistances_test.m

# %%
# !octave -W minimumDistances_test.m
# Out:
# Input:[3 2 1 2 3]
# Output:2
